# %%
import pandas as pd

# %%
df_tables = pd.read_html('https://fbref.com/pt/comps/24/Serie-A-Estatisticas')

# %%
df_tables
# Out:
# [    Cl            Equipe  MP   V   E   D  GP  GC  GD  Pt  Pts/PPJ    xG   xGA  \
#  0    1         Palmeiras  36  19   9   8  62  32  30  66      183  53.8  37.4
#  1    2  Atlético Mineiro  37  19   9   9  51  28  23  66      178  45.5  39.4
#  2    3     Botafogo (RJ)  36  18   9   9  57  34  23  63      175  48.8  46.7
#  3    4          Flamengo  36  18   9   9  54  40  14  63      175  47.9  43.7
#  4    5            Grêmio  36  19   5  12  59  54   5  62      172  46.8  52.1
#  5    6        Bragantino  36  16  11   9  47  33  14  59      164  54.9  40.7
#  6    7        Fluminense  36  16   8  12  49  43   6  56      156  47.6  43.9
#  7    8    Ath Paranaense  36  13  14   9  48  40   8  53      147  49.2  43.4
#  8    9     Internacional  37  14  10  13  43  44  -1  52      141  41.0  46.7
#  9   10         São Paulo  37  13  11  13  39  38   1  50      135  48.5  36.2
#  10  11         Fortaleza  36  13   9  14  42  43  -1  48      133  49.1  42.4
# ...

# %%
df_geral = df_tables[0]

# %%
df_geral[df_geral['Equipe'] == 'Palmeiras']
# Out:
#    Cl     Equipe  MP   V  E  D  GP  GC  GD  Pt  Pts/PPJ    xG   xGA   xGD  \
# 0   1  Palmeiras  36  19  9  8  62  32  30  66      183  53.8  37.4  16.4
#
#    xGD/90  Últimos 5  Público Artilheiro da equipe   Goleiro  Notas
# 0      45  V D V E V   22.044         Endrick - 10  Wéverton    NaN

# %%
df_geral.to_csv('D:/pythonProject/Tutoriais/data/processed/df_geral.csv')

# %%
df = pd.read_csv('D:/pythonProject/Tutoriais/data/processed/df_geral.csv')

# %%
df
# Out:
#     Unnamed: 0  Cl            Equipe  MP   V   E   D  GP  GC  GD  ...  \
# 0            0   1         Palmeiras  36  19   9   8  62  32  30  ...
# 1            1   2  Atlético Mineiro  37  19   9   9  51  28  23  ...
# 2            2   3     Botafogo (RJ)  36  18   9   9  57  34  23  ...
# 3            3   4          Flamengo  36  18   9   9  54  40  14  ...
# 4            4   5            Grêmio  36  19   5  12  59  54   5  ...
# 5            5   6        Bragantino  36  16  11   9  47  33  14  ...
# 6            6   7        Fluminense  36  16   8  12  49  43   6  ...
# 7            7   8    Ath Paranaense  36  13  14   9  48  40   8  ...
# 8            8   9     Internacional  37  14  10  13  43  44  -1  ...
# 9            9  10         São Paulo  37  13  11  13  39  38   1  ...
# 10          10  11         Fortaleza  36  13   9  14  42  43  -1  ...
# 11          11  12            Cuiabá  36  13   9  14  36  37  -1  ...
# ...
