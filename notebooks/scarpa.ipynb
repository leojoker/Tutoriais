# %%
import pandas as pd

# %%
df_tables = pd.read_html('https://fbref.com/en/players/2964fd20/Gustavo-Scarpa')

# %%
df_tables
# Out:
# [  Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                  Date                Day               Comp              Round
#  0         2023-11-12                Sun       Super League     Regular season
#  1         2023-11-05                Sun       Super League     Regular season
#  2         2023-10-30                Mon       Super League     Regular season
#  3         2023-09-24                Sun       Super League     Regular season
#  4         2023-09-17                Sun       Super League     Regular season
#
#    Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Unnamed: 7_level_0  \
#                 Venue             Result              Squad           Opponent
#  0               Away              W 2–0         Olympiacos    Asteras Tripoli
#  1               Home              L 2–4         Olympiacos               PAOK
#  2               Away              W 2–0         Olympiacos          OFI Crete
# ...
